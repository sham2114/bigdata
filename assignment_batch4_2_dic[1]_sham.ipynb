# %% [markdown]
# # Basic Dictionay Operations

# %% [markdown]
# 1. Create a dictionary with 3 key-value pairs (name, age, city).

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
print(dic)
# Out:
# {'name': 'sham', 'age': 25, 'city': 'kolhapur'}

# %% [markdown]
# 2. Create a dictionary and print the value of a specific key.

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
print(dic["name"])
# Out:
# sham

# %% [markdown]
# 3. Make a dictionary and add a new key-value pair to it.

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
dic.update({"marks":90})
print(dic)
# Out:
# {'name': 'sham', 'age': 25, 'city': 'kolhapur', 'marks': 90}

# %% [markdown]
# 4. Create a dictionary and change the value of an existing key.

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
dic.update({"age":24})
print(dic)
# Out:
# {'name': 'sham', 'age': 24, 'city': 'kolhapur'}

# %% [markdown]
# 5. Create a dictionary and remove one key using pop().

# %%
dic1={"name":"vinu","id":101,"city":"pune"}
dic1.pop("city")
print(dic1)
# Out:
# {'name': 'vinu', 'id': 101}

# %% [markdown]
# 6. Create a dictionary and remove the last inserted item using popitem().

# %%
dic2={"roll_no":1,"name":"shruti","marks":99}
dic2.popitem()
print(dic2)
# Out:
# {'roll_no': 1, 'name': 'shruti'}

# %% [markdown]
# 7. Create a dictionary and print all the keys.

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
print(dic.keys())
# Out:
# dict_keys(['name', 'age', 'city'])

# %% [markdown]
# 8. Create a dictionary and print all the values.

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
print(dic.values())
# Out:
# dict_values(['sham', 25, 'kolhapur'])

# %% [markdown]
# 9. Create a dictionary and print all the key-value items.

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
print(dic.keys(), dic.values())
# Out:
# dict_keys(['name', 'age', 'city']) dict_values(['sham', 25, 'kolhapur'])

# %% [markdown]
# 10. Make a dictionary and check the number of items using len().

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
print(len(dic))
# Out:
# 3

# %% [markdown]
# 11. Create a dictionary and check if a certain key exists (using "key" in dict).

# %%
student = {
    "name": "Ramesh",
    "age": 22,
    "course": "Big Data"
}


if "age" in student:
    print("Key exists!")
else:
    print("Key does not exist!")
# Out:
# Key exists!

# %% [markdown]
# 12. Create an empty dictionary and add two key-value pairs one by one.

# %%
dic3={}
dic3.update({"name":"sham"})
dic3.update({"age":25})
print(dic3)
# Out:
# {'name': 'sham', 'age': 25}

# %% [markdown]
# 13. Create a dictionary and update one key’s value using update().

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
dic.update({"age":26})
print(dic)
# Out:
# {'name': 'sham', 'age': 26, 'city': 'kolhapur'}

# %% [markdown]
# 14. Create two dictionaries and combine them using update().

# %%
dic3={"name":"sham","age":25,"city":"kolhapur"}
dic4={"emp_id":10,"dept":"IT"}
dic3.update(dic4)
print(dic3)
# Out:
# {'name': 'sham', 'age': 25, 'city': 'kolhapur', 'emp_id': 10, 'dept': 'IT'}

# %% [markdown]
# 15. Make a dictionary and get the value of a key using get().

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
print(dic.get("age"))
# Out:
# 25

# %% [markdown]
# 16. Create a dictionary and print its type using type().

# %%
dict={"a":1,"b":2,"c":3}
print(type(dict))
# Out:
# <class 'dict'>

# %% [markdown]
# 17. Create a dictionary and replace one value with a new one.

# %%
dict={"a":1,"b":2,"c":3}
dict.update({"b":10})
print(dict)
# Out:
# {'a': 1, 'b': 10, 'c': 3}

# %% [markdown]
# 18. Create a dictionary and clear all items using clear().

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
dic.clear()

# %% [markdown]
# 19. Create a dictionary with numbers as keys and names as values. Print the dictionary.

# %%
students = {
    1: "Sham",
    2: "Ramesh",
    3: "Suresh",
    4: "Anjali",
    5: "Deep"
}
print(students)
# Out:
# {1: 'Sham', 2: 'Ramesh', 3: 'Suresh', 4: 'Anjali', 5: 'Deep'}

# %% [markdown]
# 20. Create a dictionary and copy it into a new dictionary using copy().

# %%
dic={"name":"sham","age":25,"city":"kolhapur"}
dic6=dic.copy()
print(dic6)
# Out:
# {'name': 'sham', 'age': 25, 'city': 'kolhapur'}
